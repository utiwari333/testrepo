# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **UJJWAL TIWARI**
#
#
# Student

# %% [markdown]
# *Data science gives me a chance to play with insightful data resources and I really enjoy it. This is why I wanted to pursure data science.*

# %% [markdown]
# ### The following code intends to display the salary of the user after a year when the rate of increment is 10% per annum.

# %%
name = input("Enter your name: ")
salary = int(input("Enter your current salary: "))
newSalary = salary + salary/10
print (name , ", Your salary in the next year will be: ", newSalary)
# Out:
# Enter your name: Ujjwal
# Enter your current salary: 100
# Ujjwal , Your salary in the next year will be:  110.0

# %% [markdown]
# Benefits of Jupyter Notebooks:
#
# *****
# 1. User-interactive
# 2. Easy to use
# 3. Free (~~paid~~)
